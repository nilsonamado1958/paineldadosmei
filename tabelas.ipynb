# %% [markdown]
# # Tabela contendo todos os MEIs da cidade de São Paulo

# %%
# !pip install pandas
# !pip install pandas-profiling
import plotly.express as px
import pandas as pd
from pandas_profiling import ProfileReport
import matplotlib.pyplot as plt
import ipywidgets as widgets


tabela = pd.read_excel("BASEMEI.xlsx")

display(tabela)

tabela[['REGIAO_ATUACAO', 'SETOR_ATIVIDADE']]


tabela.REGIAO_ATUACAO.value_counts()

tabela.SETOR_ATIVIDADE.value_counts()

tabela[(tabela.REGIAO_ATUACAO == "Norte") & (tabela.SETOR_ATIVIDADE == "Comercio")]
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (1.4.4)
# Requirement already satisfied: numpy>=1.18.5 in c:\programdata\anaconda3\lib\site-packages (from pandas) (1.21.5)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pandas-profiling
#   Downloading pandas_profiling-3.6.6-py2.py3-none-any.whl (324 kB)
#      ------------------------------------ 324.4/324.4 kB 805.4 kB/s eta 0:00:00
# Collecting ydata-profiling
#   Downloading ydata_profiling-4.1.2-py2.py3-none-any.whl (345 kB)
#      -------------------------------------- 345.9/345.9 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib<3.7,>=3.2 in c:\programdata\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (3.5.2)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in c:\users\nilson amado\appdata\roaming\python\python39\site-packages (from ydata-profiling->pandas-profiling) (3.1.2)
# Collecting multimethod<1.10,>=1.4
#   Downloading multimethod-1.9.1-py3-none-any.whl (10 kB)
# Collecting imagehash==4.3.1
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
#      -------------------------------------- 296.5/296.5 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy<1.24,>=1.16.0 in c:\programdata\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (1.21.5)
# Collecting typeguard<2.14,>=2.13.2
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: seaborn<0.13,>=0.10.1 in c:\programdata\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (0.11.2)
# Requirement already satisfied: requests<2.29,>=2.24.0 in c:\programdata\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (2.28.1)
# Requirement already satisfied: scipy<1.10,>=1.4.1 in c:\programdata\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (1.9.1)
# Collecting phik<0.13,>=0.11.1
#   Downloading phik-0.12.3-cp39-cp39-win_amd64.whl (663 kB)
#      -------------------------------------- 663.5/663.5 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: tqdm<4.65,>=4.48.2 in c:\programdata\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (4.64.1)
# Collecting pydantic<1.11,>=1.8.1
#   Downloading pydantic-1.10.7-cp39-cp39-win_amd64.whl (2.2 MB)
#      ---------------------------------------- 2.2/2.2 MB 1.4 MB/s eta 0:00:00
# Collecting htmlmin==0.1.12
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pandas!=1.4.0,<1.6,>1.1 in c:\programdata\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (1.4.4)
# Collecting visions[type_image_path]==0.7.5
#   Downloading visions-0.7.5-py3-none-any.whl (102 kB)
#      -------------------------------------- 102.7/102.7 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: statsmodels<0.14,>=0.13.2 in c:\programdata\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (0.13.2)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in c:\programdata\anaconda3\lib\site-packages (from ydata-profiling->pandas-profiling) (6.0)
# Requirement already satisfied: pillow in c:\programdata\anaconda3\lib\site-packages (from imagehash==4.3.1->ydata-profiling->pandas-profiling) (9.2.0)
# Requirement already satisfied: PyWavelets in c:\programdata\anaconda3\lib\site-packages (from imagehash==4.3.1->ydata-profiling->pandas-profiling) (1.3.0)
# Collecting tangled-up-in-unicode>=0.0.4
#   Downloading tangled_up_in_unicode-0.2.0-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: networkx>=2.4 in c:\programdata\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling) (2.8.4)
# Requirement already satisfied: attrs>=19.3.0 in c:\programdata\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->ydata-profiling->pandas-profiling) (21.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling->pandas-profiling) (2.0.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib<3.7,>=3.2->ydata-profiling->pandas-profiling) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas!=1.4.0,<1.6,>1.1->ydata-profiling->pandas-profiling) (2022.1)
# Requirement already satisfied: joblib>=0.14.1 in c:\programdata\anaconda3\lib\site-packages (from phik<0.13,>=0.11.1->ydata-profiling->pandas-profiling) (1.1.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\programdata\anaconda3\lib\site-packages (from pydantic<1.11,>=1.8.1->ydata-profiling->pandas-profiling) (4.3.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests<2.29,>=2.24.0->ydata-profiling->pandas-profiling) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<2.29,>=2.24.0->ydata-profiling->pandas-profiling) (2022.9.14)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<2.29,>=2.24.0->ydata-profiling->pandas-profiling) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<2.29,>=2.24.0->ydata-profiling->pandas-profiling) (3.3)
# Requirement already satisfied: patsy>=0.5.2 in c:\programdata\anaconda3\lib\site-packages (from statsmodels<0.14,>=0.13.2->ydata-profiling->pandas-profiling) (0.5.2)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm<4.65,>=4.48.2->ydata-profiling->pandas-profiling) (0.4.5)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels<0.14,>=0.13.2->ydata-profiling->pandas-profiling) (1.16.0)
# Building wheels for collected packages: htmlmin
#   Building wheel for htmlmin (setup.py): started
#   Building wheel for htmlmin (setup.py): finished with status 'done'
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27082 sha256=42d8383ffd4971302b5d682fc8c028ecaade0208ced6ae06f057eff1c618dca9
#   Stored in directory: c:\users\nilson amado\appdata\local\pip\cache\wheels\1d\05\04\c6d7d3b66539d9e659ac6dfe81e2d0fd4c1a8316cc5a403300
# Successfully built htmlmin
# Installing collected packages: htmlmin, typeguard, tangled-up-in-unicode, pydantic, multimethod, imagehash, visions, phik, ydata-profiling, pandas-profiling
# Successfully installed htmlmin-0.1.12 imagehash-4.3.1 multimethod-1.9.1 pandas-profiling-3.6.6 phik-0.12.3 pydantic-1.10.7 tangled-up-in-unicode-0.2.0 typeguard-2.13.3 visions-0.7.5 ydata-profiling-4.1.2
#   WARNING: The script htmlmin.exe is installed in 'C:\Users\Nilson Amado\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script phik_trial.exe is installed in 'C:\Users\Nilson Amado\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts pandas_profiling.exe and ydata_profiling.exe are installed in 'C:\Users\Nilson Amado\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script pandas_profiling.exe is installed in 'C:\Users\Nilson Amado\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# C:\Users\Nilson Amado\AppData\Local\Temp\ipykernel_4832\1554834643.py:5: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport
#                  CNPJ    ABERTURA      CEP REGIAO_ATUACAO     CNAE  \
# 0      20389150000146  05/06/2014  1154010         Centro  5611205
# 1      27301378000181  14/03/2017  3186010          Leste  5611205
# 2      38252667000154  27/08/2020  2150080          Norte  5611205
# 3      34402645000172  01/08/2019  2178010          Norte  5611205
# 4      31706780000113  07/10/2018  2125001          Norte  5611205
# ...               ...         ...      ...            ...      ...
# 18038  16580796000139  26/07/2012  4146040            Sul  8599603
# 18039  12135585000136  26/05/2010  4008011            Sul  8599603
# 18040  12336610000140  07/07/2010  4140080            Sul  8599603
# 18041  11659601000127  29/10/2009  4159001            Sul  8599603
# 18042   9382868000178  14/01/2008  4007002            Sul  8599603
#
#                                      DESCRICAO_ATIVIDADE SETOR_ATIVIDADE  \
# 0      Bares e outros estabelecimentos especializados...        Comercio
# 1      Bares e outros estabelecimentos especializados...        Comercio
# 2      Bares e outros estabelecimentos especializados...        Comercio
# 3      Bares e outros estabelecimentos especializados...        Comercio
# 4      Bares e outros estabelecimentos especializados...        Comercio
# ...                                                  ...             ...
# 18038                         Treinamento em informática        Servicos
# 18039                         Treinamento em informática        Servicos
# 18040                         Treinamento em informática        Servicos
# 18041                         Treinamento em informática        Servicos
# 18042                         Treinamento em informática        Servicos
#
#                CPF                     NOME_DENOMINACAO  \
# 0      32080553828             RODRIGO AUGUSTO DA SILVA
# 1       2341725848             SOLANGE CARVALHO DA HORA
# 2       1173619500         ADRIANO CONCEICAO DOS SANTOS
# 3      41846901812             IVONALDO DE LIRA AVELINO
# 4       1632005131         STEFANY MARIA BUENO DO CARMO
# ...            ...                                  ...
# 18038   3218594804              MARTA ALVES GAMA GUERRA
# 18039  27347627818  PRISCILA VERDASCA REIS DE ALCANTARA
# 18040  25029864865       LUIZ FABIANO TEIXEIRA DE JESUS
# 18041    320901882               MIRIAM REGINA DE SOUZA
# 18042  93928807820           JOSE FRANCO PEREIRA JUNIOR
#
#                       EMAIL_CONTATO  DDD   TELEFONE  ANO_EM_ATIVIDADE
# 0               deejeyrod@gmail.com   13  991139827                 9
# 1          spd.h4d139@eturbo.com.br   11  970242164                 6
# 2      adriano_nino6656@hotmail.com   11  940268729                 3
# 3           ivonaldo.lira@gmail.com   11  965773562                 4
# 4         stefany.bueno@hotmail.com   11  940199771                 5
# ...                             ...  ...        ...               ...
# 18038         mggconsultt@gmail.com   11  958088698                11
# 18039      priverdascas@hotmail.com   11   23641504                13
# 18040       lfabianotj@yahoo.com.br   11   28928652                13
# 18041                souzamr@usp.br   11  939347489                14
# 18042  jfranco.pereira@yahoo.com.br   11  993739385                15
#
# [18043 rows x 13 columns]
#                 CNPJ    ABERTURA      CEP REGIAO_ATUACAO     CNAE  \
# 2     38252667000154  27/08/2020  2150080          Norte  5611205
# 3     34402645000172  01/08/2019  2178010          Norte  5611205
# 4     31706780000113  07/10/2018  2125001          Norte  5611205
# 28    33937881000120  15/06/2019  2010500          Norte  5611204
# 29    34686155000145  28/08/2019  2033020          Norte  5611204
# ...              ...         ...      ...            ...      ...
# 4951  13170718000178  24/05/2010  2052001          Norte  5611201
# 4952  10619434000128  26/01/2009  2187070          Norte  5611201
# 5046  37949043000128  03/08/2020  2065010          Norte  4729601
# 5047  30575209000144  28/05/2018  2176070          Norte  4729601
# 5048  27321829000142  16/03/2017  2136000          Norte  4729601
#
#                                     DESCRICAO_ATIVIDADE SETOR_ATIVIDADE  \
# 2     Bares e outros estabelecimentos especializados...        Comercio
# 3     Bares e outros estabelecimentos especializados...        Comercio
# 4     Bares e outros estabelecimentos especializados...        Comercio
# 28    Bares e outros estabelecimentos especializados...        Comercio
# 29    Bares e outros estabelecimentos especializados...        Comercio
# ...                                                 ...             ...
# 4951                           Restaurantes e similares        Comercio
# 4952                           Restaurantes e similares        Comercio
# 5046                                          Tabacaria        Comercio
# 5047                                          Tabacaria        Comercio
# 5048                                          Tabacaria        Comercio
#
#               CPF               NOME_DENOMINACAO  \
# 2      1173619500   ADRIANO CONCEICAO DOS SANTOS
# 3     41846901812       IVONALDO DE LIRA AVELINO
# 4      1632005131   STEFANY MARIA BUENO DO CARMO
# 28    25273745810    DACIO EVARISTO VUOTO JUNIOR
# 29    49465651834  LIBORIO GOMES MONFORTE JUNIOR
# ...           ...                            ...
# 4951  15420923882       LUCINETE PEREIRA RICARTE
# 4952  28835457823    FRANCINELTON RODRIGUES LIMA
# 5046   7735019831      SEBASTIAO JOSE DOS SANTOS
# 5047  32189725828      PRISCILA ROBERTA DA SILVA
# 5048  39918159820        WALLACE WILLIAN DE MELO
#
#                      EMAIL_CONTATO  DDD   TELEFONE  ANO_EM_ATIVIDADE
# 2     adriano_nino6656@hotmail.com   11  940268729                 3
# 3          ivonaldo.lira@gmail.com   11  965773562                 4
# 4        stefany.bueno@hotmail.com   11  940199771                 5
# 28       daciojunior1209@gmail.com   11  994724071                 4
# 29          mariemajoli@uol.com.br   11  986141011                 4
# ...                            ...  ...        ...               ...
# 4951    emerson_776475@hotmail.com   11   22180100                13
# 4952          naotem@naotem.com.br   11   23623262                14
# 5046      domsebastian56@gmail.com   11   45541601                 3
# 5047       priscila36@br.inter.net   11   29248681                 5
# 5048       wallace_wil@hotmail.com   11  970192782                 6
#
# [782 rows x 13 columns]

# %% [markdown]
# # Análise de dados MEI - São Paulo
#
# ## Gráfico com todos os MEIs da cidade de São Paulo separados por região
#
# ### Obs: Esse gráfico exibe a quantidade de profissionais por região.

# %%
tabela.REGIAO_ATUACAO.value_counts().plot.bar();

# %%
tabela.SETOR_ATIVIDADE.value_counts().plot.bar();

# %%
# !jupyter nbconvert --to html --no-input tabelas.ipynb
# Out:
# [NbConvertApp] Converting notebook tabelas.ipynb to html
# [NbConvertApp] Writing 665982 bytes to tabelas.html
